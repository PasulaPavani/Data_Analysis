# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv(r"C:\Users\LENOVO\Downloads\autos.csv",encoding='ISO-8859-1')
import warnings
warnings.filterwarnings("ignore")

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  object
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          333659 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              351319 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                351044 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             338142 non-null  object
#  14  brand                371528 non-null  object
# ...

# %%
data1.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
data1.rename(columns={'dateCrawled':"Datecrawled", 'name':"Name" ,'seller':"Seller", 'offerType':"OfferType", 'price':"Price", 'abtest':"Abtest",
       'vehicleType':'VehicleType', 'yearOfRegistration':"YearOfRegistration", 'gearbox':"Gearbox", 'powerPS':"PowerPS", 'model':"Model",
       'kilometer':'Kilometer', 'monthOfRegistration':"MonthOfRegistration", 'fuelType':'FuelType', 'brand':'Brand',
       'notRepairedDamage':'NotRepairedDamage', 'dateCreated':'DateCreated', 'nrOfPictures': 'NoOfPictures', 'postalCode': 'PostalCode',
       'lastSeen': 'LastSeen'},inplace=True)

# %%
data1.columns
# Out:
# Index(['Datecrawled', 'Name', 'Seller', 'OfferType', 'Price', 'Abtest',
#        'VehicleType', 'YearOfRegistration', 'Gearbox', 'PowerPS', 'Model',
#        'Kilometer', 'MonthOfRegistration', 'FuelType', 'Brand',
#        'NotRepairedDamage', 'DateCreated', 'NoOfPictures', 'PostalCode',
#        'LastSeen'],
#       dtype='object')

# %%
data1['YearOfRegistration'] = data1['YearOfRegistration'].astype('int64')

# %%
data1["YearOfRegistration"].unique()
# Out:
# array([1993, 2011, 2004, 2001, 2008, 1995, 1980, 2014, 1998, 2005, 1910,
#        2016, 2007, 2009, 2002, 2018, 1997, 1990, 2017, 1981, 2003, 1994,
#        1991, 1984, 2006, 1999, 2012, 2010, 2000, 1992, 2013, 1996, 1985,
#        1989, 2015, 1968, 1982, 1976, 1983, 1959, 1973, 1111, 1969, 1971,
#        1987, 1986, 1988, 1967, 1970, 1965, 1945, 1925, 1974, 1979, 1955,
#        1978, 1972, 1977, 1961, 1963, 1964, 1960, 1966, 1975, 1937, 1936,
#        5000, 1954, 1958, 9999, 1956, 3200, 1000, 1933, 1941, 1962, 8888,
#        1500, 2200, 4100, 1929, 1951, 1957, 1940, 3000, 2066, 1949, 2019,
#        1800, 1953, 1935, 1234, 8000, 5300, 9000, 2900, 6000, 5900, 5911,
#        1400, 1950, 4000, 1948, 1952, 1200, 8500, 1932, 1255, 1927, 1923,
#        1931, 3700, 3800, 4800, 1942, 7000, 1911, 6500, 2290, 2500, 1930,
#        1001, 6200, 9450, 1944, 1943, 1947, 1934, 1938, 1688, 2800, 1253,
#        1928, 7500, 1919, 5555, 7777, 5600, 1600, 1939, 2222, 1039, 9996,
# ...

# %%
data1=data1[data1["YearOfRegistration"].between(1885,2023)]

# %%
data1["YearOfRegistration"].unique()
# Out:
# array([1993, 2011, 2004, 2001, 2008, 1995, 1980, 2014, 1998, 2005, 1910,
#        2016, 2007, 2009, 2002, 2018, 1997, 1990, 2017, 1981, 2003, 1994,
#        1991, 1984, 2006, 1999, 2012, 2010, 2000, 1992, 2013, 1996, 1985,
#        1989, 2015, 1968, 1982, 1976, 1983, 1959, 1973, 1969, 1971, 1987,
#        1986, 1988, 1967, 1970, 1965, 1945, 1925, 1974, 1979, 1955, 1978,
#        1972, 1977, 1961, 1963, 1964, 1960, 1966, 1975, 1937, 1936, 1954,
#        1958, 1956, 1933, 1941, 1962, 1929, 1951, 1957, 1940, 1949, 2019,
#        1953, 1935, 1950, 1948, 1952, 1932, 1927, 1923, 1931, 1942, 1911,
#        1930, 1944, 1943, 1947, 1934, 1938, 1928, 1919, 1939, 1915, 1920,
#        1946], dtype=int64)

# %%
data1
# Out:
#                 Datecrawled                                          Name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         Seller OfferType  Price   Abtest VehicleType  YearOfRegistration  \
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371346 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Datecrawled          371346 non-null  object
#  1   Name                 371346 non-null  object
#  2   Seller               371346 non-null  object
#  3   OfferType            371346 non-null  object
#  4   Price                371346 non-null  int64
#  5   Abtest               371346 non-null  object
#  6   VehicleType          333659 non-null  object
#  7   YearOfRegistration   371346 non-null  int64
#  8   Gearbox              351281 non-null  object
#  9   PowerPS              371346 non-null  int64
#  10  Model                350942 non-null  object
#  11  Kilometer            371346 non-null  int64
#  12  MonthOfRegistration  371346 non-null  int64
#  13  FuelType             338096 non-null  object
#  14  Brand                371346 non-null  object
# ...

# %%
data1.isnull().sum()
# Out:
# Datecrawled                0
# Name                       0
# Seller                     0
# OfferType                  0
# Price                      0
# Abtest                     0
# VehicleType            37687
# YearOfRegistration         0
# Gearbox                20065
# PowerPS                    0
# Model                  20404
# Kilometer                  0
# MonthOfRegistration        0
# FuelType               33250
# Brand                      0
# NotRepairedDamage      71904
# DateCreated                0
# NoOfPictures               0
# PostalCode                 0
# LastSeen                   0
# dtype: int64

# %%
data1["MonthOfRegistration"].unique()
# Out:
# array([ 0,  5,  8,  6,  7, 10, 12, 11,  2,  3,  1,  4,  9], dtype=int64)

# %%
data1=data1[data1["MonthOfRegistration"].between(1,12)]

# %%
data1["MonthOfRegistration"].unique()
# Out:
# array([ 5,  8,  6,  7, 10, 12, 11,  2,  3,  1,  4,  9], dtype=int64)

# %%
data1
# Out:
#                 Datecrawled  \
# 1       2016-03-24 10:58:45
# 2       2016-03-14 12:52:21
# 3       2016-03-17 16:54:04
# 4       2016-03-31 17:25:20
# 5       2016-04-04 17:36:23
# ...                     ...
# 371523  2016-03-14 17:48:27
# 371524  2016-03-05 19:56:21
# 371525  2016-03-19 18:57:12
# 371526  2016-03-20 19:41:08
# 371527  2016-03-07 19:39:19
#
#                                                      Name  Seller OfferType  \
# 1                                    A5_Sportback_2.7_Tdi  privat   Angebot
# 2                          Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3                                      GOLF_4_1_4__3TÜRER  privat   Angebot
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# ...                                                   ...     ...       ...
# 371523                         Suche_t4___vito_ab_6_sitze  privat   Angebot
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333809 entries, 1 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Datecrawled          333809 non-null  object
#  1   Name                 333809 non-null  object
#  2   Seller               333809 non-null  object
#  3   OfferType            333809 non-null  object
#  4   Price                333809 non-null  int64
#  5   Abtest               333809 non-null  object
#  6   VehicleType          311037 non-null  object
#  7   YearOfRegistration   333809 non-null  int64
#  8   Gearbox              323510 non-null  object
#  9   PowerPS              333809 non-null  int64
#  10  Model                319946 non-null  object
#  11  Kilometer            333809 non-null  int64
#  12  MonthOfRegistration  333809 non-null  int64
#  13  FuelType             314222 non-null  object
#  14  Brand                333809 non-null  object
# ...

# %%
data1.isnull().sum()
# Out:
# Datecrawled                0
# Name                       0
# Seller                     0
# OfferType                  0
# Price                      0
# Abtest                     0
# VehicleType            22772
# YearOfRegistration         0
# Gearbox                10299
# PowerPS                    0
# Model                  13863
# Kilometer                  0
# MonthOfRegistration        0
# FuelType               19587
# Brand                      0
# NotRepairedDamage      49731
# DateCreated                0
# NoOfPictures               0
# PostalCode                 0
# LastSeen                   0
# dtype: int64

# %%
sns.boxplot(data=data1,x="Price")
# Out:
# <Axes: xlabel='Price'>

# %%
sns.distplot(data1["Price"])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
data1=data1.drop(data1[data1["Price"]>40000.0].index)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 331190 entries, 1 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Datecrawled          331190 non-null  object
#  1   Name                 331190 non-null  object
#  2   Seller               331190 non-null  object
#  3   OfferType            331190 non-null  object
#  4   Price                331190 non-null  int64
#  5   Abtest               331190 non-null  object
#  6   VehicleType          308444 non-null  object
#  7   YearOfRegistration   331190 non-null  int64
#  8   Gearbox              320981 non-null  object
#  9   PowerPS              331190 non-null  int64
#  10  Model                317592 non-null  object
#  11  Kilometer            331190 non-null  int64
#  12  MonthOfRegistration  331190 non-null  int64
#  13  FuelType             311704 non-null  object
#  14  Brand                331190 non-null  object
# ...

# %%
data1.isnull().sum()
# Out:
# Datecrawled                0
# Name                       0
# Seller                     0
# OfferType                  0
# Price                      0
# Abtest                     0
# VehicleType            22746
# YearOfRegistration         0
# Gearbox                10209
# PowerPS                    0
# Model                  13598
# Kilometer                  0
# MonthOfRegistration        0
# FuelType               19486
# Brand                      0
# NotRepairedDamage      49641
# DateCreated                0
# NoOfPictures               0
# PostalCode                 0
# LastSeen                   0
# dtype: int64

# %%
(data1.isnull().sum()/(len(data1)))*100
# Out:
# Datecrawled             0.000000
# Name                    0.000000
# Seller                  0.000000
# OfferType               0.000000
# Price                   0.000000
# Abtest                  0.000000
# VehicleType             6.867961
# YearOfRegistration      0.000000
# Gearbox                 3.082521
# PowerPS                 0.000000
# Model                   4.105800
# Kilometer               0.000000
# MonthOfRegistration     0.000000
# FuelType                5.883632
# Brand                   0.000000
# NotRepairedDamage      14.988677
# DateCreated             0.000000
# NoOfPictures            0.000000
# PostalCode              0.000000
# LastSeen                0.000000
# dtype: float64

# %%
data1['VehicleType']=data1['VehicleType'].fillna(data1["VehicleType"].mode()[0])

# %%
data1['Gearbox']=data1['Gearbox'].fillna(data1["Gearbox"].mode()[0])

# %%
data1['Model']=data1['Model'].fillna(data1["Model"].mode()[0])

# %%
data1['NotRepairedDamage']=data1['NotRepairedDamage'].fillna(data1['NotRepairedDamage'].mode()[0])

# %%
data1['FuelType']=data1['FuelType'].fillna(data1["FuelType"].mode()[0])

# %%
data1.isnull().sum()
# Out:
# Datecrawled            0
# Name                   0
# Seller                 0
# OfferType              0
# Price                  0
# Abtest                 0
# VehicleType            0
# YearOfRegistration     0
# Gearbox                0
# PowerPS                0
# Model                  0
# Kilometer              0
# MonthOfRegistration    0
# FuelType               0
# Brand                  0
# NotRepairedDamage      0
# DateCreated            0
# NoOfPictures           0
# PostalCode             0
# LastSeen               0
# dtype: int64

# %%
data1['Datecrawled'] = pd.to_datetime(data1['Datecrawled'])

# %%
data1["YearOfRgistration"]=pd.to_datetime(data1["Datecrawled"])

# %%
data1['DateCreated'] = pd.to_datetime(data1['DateCreated'])

# %%
data1.loc[data1["Seller"]=="privat","Seller"]="Private"

# %%
data1.loc[data1["Gearbox"]=="automatik","Gearbox"]="Automatic"

# %%
data1.loc[data1["Gearbox"]=="manuell","Gearbox"]="Manual"

# %%
data1["PostalCode"]=data1["PostalCode"].astype(int)

# %%
data1["NoOfPictures"]=data1["NoOfPictures"].astype(int)

# %%
data1["Kilometer"]=data1["Kilometer"].astype(float)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 331190 entries, 1 to 371527
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Datecrawled          331190 non-null  datetime64[ns]
#  1   Name                 331190 non-null  object
#  2   Seller               331190 non-null  object
#  3   OfferType            331190 non-null  object
#  4   Price                331190 non-null  int64
#  5   Abtest               331190 non-null  object
#  6   VehicleType          331190 non-null  object
#  7   YearOfRegistration   331190 non-null  int64
#  8   Gearbox              331190 non-null  object
#  9   PowerPS              331190 non-null  int64
#  10  Model                331190 non-null  object
#  11  Kilometer            331190 non-null  float64
#  12  MonthOfRegistration  331190 non-null  int64
#  13  FuelType             331190 non-null  object
# ...

# %%
data1.describe()
# Out:
#                Price  YearOfRegistration        PowerPS      Kilometer  \
# count  331190.000000       331190.000000  331190.000000  331190.000000
# mean     5659.978275         2003.548187     119.050255  125961.276005
# std      6424.601416            7.306570     182.968876   38983.626615
# min         0.000000         1910.000000       0.000000    5000.000000
# 25%      1300.000000         1999.000000      75.000000  100000.000000
# 50%      3250.000000         2004.000000     109.000000  150000.000000
# 75%      7599.000000         2008.000000     150.000000  150000.000000
# max     40000.000000         2019.000000   20000.000000  150000.000000
#
#        MonthOfRegistration  NoOfPictures     PostalCode
# count        331190.000000      331190.0  331190.000000
# mean              6.385742           0.0   51130.381265
# std               3.348812           0.0   25750.499338
# min               1.000000           0.0    1067.000000
# ...

# %%
data1.describe()
# Out:
#                Price  YearOfRegistration        PowerPS      Kilometer  \
# count  331190.000000       331190.000000  331190.000000  331190.000000
# mean     5659.978275         2003.548187     119.050255  125961.276005
# std      6424.601416            7.306570     182.968876   38983.626615
# min         0.000000         1910.000000       0.000000    5000.000000
# 25%      1300.000000         1999.000000      75.000000  100000.000000
# 50%      3250.000000         2004.000000     109.000000  150000.000000
# 75%      7599.000000         2008.000000     150.000000  150000.000000
# max     40000.000000         2019.000000   20000.000000  150000.000000
#
#        MonthOfRegistration  NoOfPictures     PostalCode
# count        331190.000000      331190.0  331190.000000
# mean              6.385742           0.0   51130.381265
# std               3.348812           0.0   25750.499338
# min               1.000000           0.0    1067.000000
# ...

# %%
data1.loc[data1.duplicated(keep="first"),:]
# Out:
#                Datecrawled                                          Name  \
# 179448 2016-03-08 18:42:48  Mercedes_Benz_CLK_Coupe_230_Kompressor_Sport
# 242556 2016-03-28 00:56:10                                  Suzuki_Ignis
# 270719 2016-04-03 09:01:15                    Mercedes_Benz_CLK_320_W209
# 341474 2016-03-18 18:46:15    Volkswagen_Passat_Variant_1.9_TDI_Highline
#
#          Seller OfferType  Price   Abtest VehicleType  YearOfRegistration  \
# 179448  Private   Angebot   1799     test       coupe                1999
# 242556  Private   Angebot   1000  control  kleinwagen                2002
# 270719  Private   Angebot   4699     test       coupe                2003
# 341474  Private   Angebot   1999  control       kombi                2001
#
#           Gearbox  PowerPS  ... Kilometer  MonthOfRegistration  FuelType  \
# 179448  Automatic      193  ...   20000.0                    7    benzin
# 242556     Manual       83  ...  150000.0                    1    benzin
# ...

# %%
data1=data1.drop_duplicates(keep="first")

# %%
data1.reset_index(drop=True,inplace=True)

# %%
data1
# Out:
#                Datecrawled                                               Name  \
# 0      2016-03-24 10:58:45                               A5_Sportback_2.7_Tdi
# 1      2016-03-14 12:52:21                     Jeep_Grand_Cherokee_"Overland"
# 2      2016-03-17 16:54:04                                 GOLF_4_1_4__3TÜRER
# 3      2016-03-31 17:25:20                     Skoda_Fabia_1.4_TDI_PD_Classic
# 4      2016-04-04 17:36:23  BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...
# ...                    ...                                                ...
# 331181 2016-03-14 17:48:27                         Suche_t4___vito_ab_6_sitze
# 331182 2016-03-05 19:56:21              Smart_smart_leistungssteigerung_100ps
# 331183 2016-03-19 18:57:12                 Volkswagen_Multivan_T4_TDI_7DC_UY2
# 331184 2016-03-20 19:41:08                             VW_Golf_Kombi_1_9l_TDI
# 331185 2016-03-07 19:39:19       BMW_M135i_vollausgestattet_NP_52.720____Euro
#
# ...

# %%
data1.to_csv("cleaned_autos_dataset.csv",index=False)
